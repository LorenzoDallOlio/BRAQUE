# %%
import pandas as pd

import braque


# load necessary dbs

original_db = pd.read_csv("./original_db-toy.csv")
pos = pd.read_csv("./positions-toy.csv")
reference = pd.read_csv("./reference-toy.csv")

# %%
# start of the analysis

# minimal initialization of BRAQUE object
analysis = braque.BRAQUE(original_db=original_db, 
                         pos=pos,
                         reference=reference, 
                         # names from reference-toy.csv headers, minimal initialization requires 4 columns:
                         correspondence_column='Feature', 
                         naming_column='Official Name', 
                         interpretative_column='Significance', 
                         importance_column='Important')


# run the whole pipeline with standard parameters
analysis.run_pipeline()
# Out:
# data loaded
# Features Selection ... 2023-06-16 17:01:56.766508
# Lognormal Shrinkage ... 2023-06-16 17:01:56.773489
# Initialization 0
# Initialization converged: True	 time lapse 0.17010s	 ll -59.44587
# Initialization 0
# Initialization converged: True	 time lapse 0.08768s	 ll 128.52616
# Initialization 0
# Initialization converged: True	 time lapse 0.07858s	 ll -20.97418
# Initialization 0
# Initialization converged: True	 time lapse 0.04236s	 ll -1.76006
# Initialization 0
# Initialization converged: True	 time lapse 0.09990s	 ll 163.33670
# Initialization 0
# Initialization converged: True	 time lapse 0.19617s	 ll 6.72586
# Initialization 0
# Initialization converged: True	 time lapse 0.11924s	 ll -9.63494
# UMAP embedding ... 2023-06-16 17:01:57.812889
# UMAP(min_dist=0.0, n_neighbors=50, random_state=42, verbose=True)
# Fri Jun 16 17:01:57 2023 Construct fuzzy simplicial set
# Fri Jun 16 17:01:57 2023 Finding Nearest Neighbors
# Fri Jun 16 17:01:59 2023 Finished Nearest Neighbor Search
# Fri Jun 16 17:02:02 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Fri Jun 16 17:02:03 2023 Finished embedding
# HDBSCAN clustering ... 2023-06-16 17:02:06.998762
# Computing features importance per cluster... 2023-06-16 17:02:07.204199
# Plots section ... 2023-06-16 17:02:07.228906
# /home/PERSONALE/lorenzo.dallolio4/cell-clustering/braque.py:374: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.db.loc[:, "MainFeatures"][mask] = ''
# /home/PERSONALE/lorenzo.dallolio4/cell-clustering/braque.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.db.loc[:, self.interpretative_column][mask] = ''
# /home/PERSONALE/lorenzo.dallolio4/cell-clustering/braque.py:1111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_db2.loc[:,'cluster'] = 'whole sample'
# /home/PERSONALE/lorenzo.dallolio4/cell-clustering/braque.py:1111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_db2.loc[:,'cluster'] = 'whole sample'
# /home/PERSONALE/lorenzo.dallolio4/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# /home/PERSONALE/lorenzo.dallolio4/cell-clustering/braque.py:1111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_db2.loc[:,'cluster'] = 'whole sample'
# Saving results ... 2023-06-16 17:02:11.632081
# Pipeline completed! 2023-06-16 17:02:11.655428

# %%
# Once the analysis is completed, all the important steps will be stored in a
# minimal initialization for all premade steps loading results instead of computing them
analysis = braque.BRAQUE(original_db=original_db, 
                         pos=pos,
                         reference=reference, 
                         # names from reference-toy.csv headers, minimal initialization requires 4 columns:
                         correspondence_column='Feature', 
                         naming_column='Official Name', 
                         interpretative_column='Significance', 
                         importance_column='Important',
                         # it is possible to change other parameters when you load premade-steps, 
                         # but the 'area' parameter must be identical to the one used previously
                         load_db=True, 
                         load_embed=True,
                         load_clusters=True)
# Out:
# Loading preprocessed db...
# Loading UMAP embedding...
# Loading precomputed clusters...
